# %%
# !pip install --pre torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/nightly/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/nightly/cu116
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !cd yolov5 && python train.py --img 320 --batch 128 --epochs 1 --data C:\Users\97450\RIFLE_updated\custome_data.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=C:Users97450RIFLE_updatedcustome_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1, batch_size=128, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# Traceback (most recent call last):
#   File "train.py", line 632, in <module>
#     main(opt)
#   File "train.py", line 501, in main
#     check_file(opt.data), check_yaml(opt.cfg), check_yaml(opt.hyp), str(opt.weights), str(opt.project)  # checks
# ...

# %% [markdown]
# # run from here and below

# %%
import torch
#from matplotlib import pyplot as plt
import cv2
#import uuid 
#import os
#import time
import numpy as np
import pandas

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path= r"C:\Users\97450\RIFLE_updated\yolov5\runs\train\exp8\weights\last.pt", force_reload=True)  # or yolov5n - yolov5x6, custom
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\97450/.cache\torch\hub\master.zip
# YOLOv5  2022-10-16 Python-3.9.7 torch-1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 8192MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
model.conf = 0.5

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    results = model(frame)

    cv2.imshow('Rowaids', np.squeeze(results.render()))
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
#img=cv2.imread(r"C:\Users\aboal\GUNS_UPDATED\export\images\train\M4.812f1f0b-245d-11ed-8cc6-0456e5bbf584.jpg")
results = model(img)
img=np.uint8(img)

cv2.imshow('Rowaids', np.squeeze(results.render()))
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14392/1958427970.py in <module>
#       1 #img=cv2.imread(r"C:\Users\aboal\GUNS_UPDATED\export\images\train\M4.812f1f0b-245d-11ed-8cc6-0456e5bbf584.jpg")
# ----> 2 results = model(img)
#       3 img=np.uint8(img)
#       4
#       5 cv2.imshow('Rowaids', np.squeeze(results.render()))
#
# NameError: name 'img' is not defined

# %%
rtsp_url= "rtsp://admin:123456@192.168.1.13"


cap = cv2.VideoCapture(rtsp_url)
while cap.isOpened():
    ret, frame = cap.read()
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
